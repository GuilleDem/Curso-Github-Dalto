# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilleDem/Curso-Github-Dalto/blob/main/DA_DESDAFIO_LATAM_ipynb_(interactive_python_notebook).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CURSO DATA ANALYST - DESAFIO LATAM

# %% [markdown]
# #Curso de **Python**

# %%
#Variable entero > Int
a= 4

# %%
#Variable flotante > Float
b= 6/3

# %%
#Variable texto > String 'str' > entre comillas "" o ''
c= 'hola '

# %%
#Puedo sumar las variables de texto
d= 'mundo'

# %%
c+d
# Out:
# 'hola mundo'

# %%
#La variable type me sirve para ver que tipo de elemento es
type(d)
# Out:
# str

# %%
#Método para las listas
#nombre_lista.append() > para agregar un elemento a la lista

# %% [markdown]
# **Librerias mas usadas en análisis de datos en PYTHON**

# %%
#Pandas es la librería básica para la manipulación y análisis de datos
import pandas as pd
